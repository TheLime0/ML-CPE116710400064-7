# %% [markdown]
# # Nutritional Analysis of Foods Using USDA Data
#
# This project dives into the nutritional composition of foods, analyzing data from the United States Department of Agriculture's Food Composition Database. The objective was to identify foods with high levels of nutrients that can be detrimental in excess, like sugars and fats, while also highlighting nutrient-rich options. Through this analysis, valuable insights emerged about food composition, particularly the types of sugars, fats, and vitamins in various foods, which can influence dietary choices.
#
# ## Key Insights and Findings
#
# ### High-Sugar Foods:
#
# Analysis of the top 20 sugar-rich foods revealed Strawberry beverage powder as the top item with more sugar content from the food items analized in the dataset. Many of these items with high sugar content are candies, like pineapple, butterscotch and tamarind candy. However, caution is required when interpreting this data, as not all sugars have the same impact. For example, foods like fruit peel, whey, and sweet potato paste contain sugars in fiber or polysaccharide forms, which differ in metabolic impact from monosaccharides or processed sugars.
#
# ### High-Fat Foods:
#
# Items with the highest fat content include fat back, salt pork, and macadamia nuts. Notably:
# Fat back and salt pork contain more than 50% of their total fat as polysaturated and saturated fats.
# Macadamia nuts are high in monounsaturated fats, which are generally considered healthier.
#
# ### Vitamin-Rich Foods:
#
# Foods with substantial vitamin content include beef liver, Kellogg's Cocoa Krispies, and Kellogg's S'mores. Among these:
# Beef liver stands out for its Vitamin A content.
# Kellogg's cereals provide a significant amount of vitamins, though they contain until 20 g of sugar, barely down from the recomended daily dosis intake, according to WHO (roughly 25 g), which could detract from their nutritional benefits.
#
# Foods like vegetable mixes and sweet potato chips show relatively high vitamin content but are also notably high in fats, creating an imbalance that may diminish their overall health benefits. While they provide essential vitamins, the elevated fat levels—often from added oils—suggest that these foods may not be the healthiest choices despite their nutrient density, this will depend on individual dietary needs.

# %% [markdown]
# ## General light cleaning

# %%
library("tidyverse")
food_data <-read_csv("/kaggle/input/food-vitamins-minerals-macronutrient/food.csv")
colnames(food_data)


colnames(food_data) = gsub("Data.", "", colnames(food_data))
colnames(food_data) = gsub("Vitamins.", "", colnames(food_data)) 
colnames(food_data) = gsub("Fat.", "", colnames(food_data)) 
colnames(food_data) = gsub("Major Minerals.", "", colnames(food_data)) 
colnames(food_data)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.4.4     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Rows: 7083 Columns: 38
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (2): Category, Description
# dbl (36): Nutrient Data Bank Number, Data.Alpha Carotene, Data.Beta Carotene...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#  [1] "Category"                       "Description"
#  [3] "Nutrient Data Bank Number"      "Data.Alpha Carotene"
#  [5] "Data.Beta Carotene"             "Data.Beta Cryptoxanthin"
#  [7] "Data.Carbohydrate"              "Data.Cholesterol"
#  [9] "Data.Choline"                   "Data.Fiber"
# [11] "Data.Lutein and Zeaxanthin"     "Data.Lycopene"
# [13] "Data.Niacin"                    "Data.Protein"
# [15] "Data.Retinol"                   "Data.Riboflavin"
# [17] "Data.Selenium"                  "Data.Sugar Total"
# [19] "Data.Thiamin"                   "Data.Water"
# [21] "Data.Fat.Monosaturated Fat"     "Data.Fat.Polysaturated Fat"
# [23] "Data.Fat.Saturated Fat"         "Data.Fat.Total Lipid"
# [25] "Data.Major Minerals.Calcium"    "Data.Major Minerals.Copper"
# [27] "Data.Major Minerals.Iron"       "Data.Major Minerals.Magnesium"
# [29] "Data.Major Minerals.Phosphorus" "Data.Major Minerals.Potassium"
# [31] "Data.Major Minerals.Sodium"     "Data.Major Minerals.Zinc"
# [33] "Data.Vitamins.Vitamin A - RAE"  "Data.Vitamins.Vitamin B12"
# [35] "Data.Vitamins.Vitamin B6"       "Data.Vitamins.Vitamin C"
# [37] "Data.Vitamins.Vitamin E"        "Data.Vitamins.Vitamin K"
#  [1] "Category"              "Description"           "Nutrient Bank Number"
#  [4] "Alpha Carotene"        "Beta Carotene"         "Beta Cryptoxanthin"
#  [7] "Carbohydrate"          "Cholesterol"           "Choline"
# [10] "Fiber"                 "Lutein and Zeaxanthin" "Lycopene"
# [13] "Niacin"                "Protein"               "Retinol"
# [16] "Riboflavin"            "Selenium"              "Sugar Total"
# [19] "Thiamin"               "Water"                 "Monosaturated Fat"
# [22] "Polysaturated Fat"     "Saturated Fat"         "Total Lipid"
# [25] "Calcium"               "Copper"                "Iron"
# [28] "Magnesium"             "Phosphorus"            "Potassium"
# [31] "Sodium"                "Zinc"                  "Vitamin A - RAE"
# [34] "Vitamin B12"           "Vitamin B6"            "Vitamin C"
# [37] "Vitamin E"             "Vitamin K"

# %%
library("dplyr")
average_measurements <-food_data %>% 
                      group_by(Category) %>%
                      summarise(
                               across(
                               where(is.numeric), mean, na.rm = TRUE))
as_tibble(average_measurements)
# Out:
# Warning message:
# “There was 1 warning in `summarise()`.
# ℹ In argument: `across(where(is.numeric), mean, na.rm = TRUE)`.
# ℹ In group 1: `Category = "100 GRAND Bar"`.
# Caused by warning:
# ! The `...` argument of `across()` is deprecated as of dplyr 1.1.0.
# Supply arguments directly to `.fns` through an anonymous function instead.
#
#   # Previously
#   across(a:b, mean, na.rm = TRUE)
#
#   # Now
#   across(a:b, \(x) mean(x, na.rm = TRUE))”
#      Category                                        Nutrient Bank Number
# 1    100 GRAND Bar                                   91715300
# 2    3 MUSKETEERS Bar                                91726420
# 3    3 Musketeers Truffle Crisp Bar                  91726425
# 4    Abalone                                         26301137
# 5    Adobo                                           58143915
# 6    Agave liquid sweetener                          91302020
# 7    Air filled fritter or fried puff                53420300
# 8    Alcoholic malt beverage                         93106037
# 9    Alexander                                       93301010
# 10   Alfalfa sprouts                                 75100500
# 11   Alfredo sauce                                   14650160
# 12   Alfredo sauce with added vegetables             14650165
# 13   Alfredo sauce with meat                         14650170
# 14   Alfredo sauce with meat and added vegetables    14650175
# 15   Alfredo sauce with poultry                      14650180
# 16   Alfredo sauce with poultry and added vegetables 14650185
# 17   Alfredo sauce with seafood                      14650190
# 18   Alfredo sauce with seafood and added vegetables 14650195
# 19   Almond butter                                   42200505
# 20   Almond chicken                                  27445250
# 21   Almond milk                                     11350015
# 22   Almond oil                                      82101300
# 23   Almond paste                                    42200600
# 24   Almonds                                         56981017
# 25   Aloe vera juice drink                           75200700
# 26   Ambrosia                                        63301010
# 27   Anchovy                                         26101145
# 28   Animal fat or drippings                         81201000
# 29   Anisette toast                                  51187020
# 30   Antipasto with ham                              27460510
# 2428 0.0800000   11.2000000
# 2429 2.4400000    0.9000000

# %% [markdown]
# ## Sugar analysis

# %%
#What foods have more sugar?
top_sugar<- average_measurements %>%
             arrange(desc(`Sugar Total`))%>% 
             select(Category,`Sugar Total`)%>%
             slice_head(n = 20)
as_tibble(top_sugar)
# Out:
#    Category                         Sugar Total
# 1  Sugar substitute and sugar blend 99.220
# 2  Sugar                            97.484
# 3  Strawberry beverage powder       95.450
# 4  Pineapple candy                  83.750
# 5  Honey                            82.120
# 6  Fruit peel                       80.680
# 7  Butterscotch hard candy          80.460
# 8  Fondant                          80.160
# 9  Tamarind candy                   78.570
# 10 Corn syrup                       76.770
# 11 Pralines                         75.850
# 12 Skittles                         75.840
# 13 Molasses                         74.720
# 14 Whey                             74.460
# 15 Meringues                        73.060
# 16 Guava paste                      71.620
# 17 Sweet potato paste               71.580
# 18 Dietetic or low calorie gumdrops 70.000
# 19 Licorice                         70.000
# 20 Mexican chocolate                69.400

# %%
#First and second result are literally sugar, we won't take them on count.
top_sugar_V2<-top_sugar%>%
              slice(-1,-2)%>%
              mutate(Category = factor(Category, levels = unique(Category)))%>%
              slice_head(n = 20)
as_tibble(top_sugar_V2)
# Out:
#    Category                         Sugar Total
# 1  Strawberry beverage powder       95.45
# 2  Pineapple candy                  83.75
# 3  Honey                            82.12
# 4  Fruit peel                       80.68
# 5  Butterscotch hard candy          80.46
# 6  Fondant                          80.16
# 7  Tamarind candy                   78.57
# 8  Corn syrup                       76.77
# 9  Pralines                         75.85
# 10 Skittles                         75.84
# 11 Molasses                         74.72
# 12 Whey                             74.46
# 13 Meringues                        73.06
# 14 Guava paste                      71.62
# 15 Sweet potato paste               71.58
# 16 Dietetic or low calorie gumdrops 70.00
# 17 Licorice                         70.00
# 18 Mexican chocolate                69.40

# %%
colnames(top_sugar_V2) = gsub("Sugar Total", "Total Sugar", colnames(top_sugar_V2)) 
colnames(top_sugar_V2)
# Out:
# [1] "Category"    "Total Sugar"

# %%
ggplot(
    data=top_sugar_V2)+ 
geom_col (
    mapping= aes(x=Category, y=`Total Sugar`, fill=`Total Sugar`))+ 
scale_fill_gradient(
    low = "hotpink2", 
    high = "hotpink4")+
theme(
   axis.text.x=element_text(angle=90,hjust = 1, vjust = 1,size = 12),
   axis.text.y=element_text(size = 12),
   axis.title.x = element_text(size = 14), 
   axis.title.y = element_text(size = 14),
   plot.title = element_text(hjust = 0.5, size = 16, face="bold"))+
labs(
    title= "Top 20 foods with more sugar content",
    caption= "Source:ARS USDA Dataset", 
    y= "Total sugar (g)")

# %% [markdown]
# Products like sugar and oils were logically listed as those with the highest content of sugar and fat, respectively, we needed the table to focus on foods typically consumed alone, rather than merely as ingredients. From the analysis of the top 20 items with the most sugar, it is evident that many are candies, such as pineapple and tamarind candy. However, we must approach this information cautiously because some items like fruit peel, whey, or sweet potato paste contain different types of sugars, such as those found in fiber or polysaccharides, which do not affect the body in the same way as monosaccharides and processed sugars.

# %% [markdown]
# ## Fat analysis

# %%
#What foods have more fats?
top_lipids<- average_measurements %>%
             arrange(desc(`Total Lipid`))%>% 
             select(Category,`Total Lipid`)%>%
             slice_head(n = 20)
as_tibble(top_lipids)
# Out:
#    Category                             Total Lipid
# 1  Almond oil                           100.00
# 2  Canola oil                           100.00
# 3  Corn oil                             100.00
# 4  Cottonseed oil                       100.00
# 5  Industrial oil as ingredient in food 100.00
# 6  Lard                                 100.00
# 7  Olive oil                            100.00
# 8  Peanut oil                           100.00
# 9  Safflower oil                        100.00
# 10 Sesame oil                           100.00
# 11 Soybean oil                          100.00
# 12 Sunflower oil                        100.00
# 13 Vegetable oil                        100.00
# 14 Walnut oil                           100.00
# 15 Wheat germ oil                       100.00
# 16 Flaxseed oil                          99.98
# 17 Shortening                            99.97
# 18 Ghee                                  99.48
# 19 Coconut oil                           99.10
# 20 Animal fat or drippings               92.18

# %%
#Discarding actual oils used as ingredients.
top_lipids_V2<- average_measurements %>% 
                arrange(desc(`Total Lipid`))%>% 
                select(Category,`Total Lipid`)%>%
                mutate(Category = factor(Category, levels = unique(Category)))%>%
                slice(-(1:21))%>%
                slice_head(n = 20)
as_tibble(top_lipids_V2)
# Out:
#    Category           Total Lipid
# 1  Fat back           81.9300
# 2  Salt pork          81.9300
# 3  Macadamia nuts     76.0800
# 4  Table fat          74.6800
# 5  Butter             73.9050
# 6  Butter-oil blend   73.2025
# 7  Garlic sauce       73.0500
# 8  Lemon-butter sauce 73.0200
# 9  Pecans             69.4540
# 10 Margarine          68.5200
# 11 Pine nuts          68.3700
# 12 Brazil nuts        67.1000
# 13 Pork skin          65.5500
# 14 Sesame seeds       61.2100
# 15 Hazelnuts          60.7500
# 16 Walnuts            59.5400
# 17 Pesto sauce        59.1700
# 18 Hollandaise sauce  56.6500
# 19 Fry sauce          56.1600
# 20 Almond butter      55.5000

# %%
ggplot(
    data=top_lipids_V2)+ 
geom_col (
    mapping= aes(x=Category, y=`Total Lipid`, fill=`Total Lipid`))+ 
scale_fill_gradient(
    low = "hotpink2", 
    high = "hotpink4")+
theme(
   axis.text.x=element_text(angle=90,hjust = 1, vjust = 1,size = 12),
   axis.text.y=element_text(size = 12),
   axis.title.x = element_text(size = 14), 
   axis.title.y = element_text(size = 14),
   plot.title = element_text(hjust = 0.5, size = 16, face="bold"))+
labs(
    title= "Top 20 foods with more lipids content",
    caption= "Source:ARS USDA Dataset", 
    y= "Total lipids (g)")

# %%
top_lipids_V3<- average_measurements %>% 
                arrange(desc(`Total Lipid`))%>% 
                select(Category,`Total Lipid`, `Saturated Fat`,
                        `Monosaturated Fat`, `Polysaturated Fat` )%>%
                mutate(Category = factor(Category, levels = unique(Category)))%>%
                slice(-(1:21))%>%
                slice_head(n = 20)
as_tibble(top_lipids_V3)
# Out:
#    Category           Total Lipid Saturated Fat Monosaturated Fat
# 1  Fat back           81.9300     31.33900      36.64000
# 2  Salt pork          81.9300     31.33900      36.64000
# 3  Macadamia nuts     76.0800     11.94700      59.27500
# 4  Table fat          74.6800     35.96600      22.30500
# 5  Butter             73.9050     45.61175      19.46075
# 6  Butter-oil blend   73.2025     44.11725      19.17400
# 7  Garlic sauce       73.0500     46.24000      18.92000
# 8  Lemon-butter sauce 73.0200     46.23500      18.92000
# 9  Pecans             69.4540      6.12420      38.89620
# 10 Margarine          68.5200     13.37900      27.48500
# 11 Pine nuts          68.3700      4.89900      18.76400
# 12 Brazil nuts        67.1000     16.13400      23.87900
# 13 Pork skin          65.5500     23.65700      28.74600
# 14 Sesame seeds       61.2100      9.05500      23.92400
# 15 Hazelnuts          60.7500      4.46400      45.65200
# 16 Walnuts            59.5400      5.80250       9.54700
# 17 Pesto sauce        59.1700      9.58400      35.18000
# 18 Hollandaise sauce  56.6500     33.69000      16.13500
# 19 Fry sauce          56.1600      8.78100      12.63600
# 20 Almond butter      55.5000      6.55000      32.44500
#    Polysaturated Fat
# 1  10.74400
# 2  10.74400
# 3   1.49800
# 4  12.19900
# 5   2.86575
# 6   2.93775
# 7   2.76400
# 8   2.74100
# 9  21.20800
# 10 25.57067
# 11 34.07100
# 12 24.39900
# 13 11.44200
# 14 25.49100
# 15  7.92000
# 16 41.50650
# 17 10.51500
# 18  3.08900
# 19 33.52800
# 20 13.61300

# %%
top_lipids_V3_long <- top_lipids_V3 %>%
                      pivot_longer(
                          cols = c(`Saturated Fat`,`Monosaturated Fat`, `Polysaturated Fat`),
                          names_to = "Fat_Type",
                          values_to = "Fat_Value")
as_tibble(top_lipids_V3_long)
# Out:
#    Category           Total Lipid Fat_Type          Fat_Value
# 1  Fat back           81.9300     Saturated Fat     31.33900
# 2  Fat back           81.9300     Monosaturated Fat 36.64000
# 3  Fat back           81.9300     Polysaturated Fat 10.74400
# 4  Salt pork          81.9300     Saturated Fat     31.33900
# 5  Salt pork          81.9300     Monosaturated Fat 36.64000
# 6  Salt pork          81.9300     Polysaturated Fat 10.74400
# 7  Macadamia nuts     76.0800     Saturated Fat     11.94700
# 8  Macadamia nuts     76.0800     Monosaturated Fat 59.27500
# 9  Macadamia nuts     76.0800     Polysaturated Fat  1.49800
# 10 Table fat          74.6800     Saturated Fat     35.96600
# 11 Table fat          74.6800     Monosaturated Fat 22.30500
# 12 Table fat          74.6800     Polysaturated Fat 12.19900
# 13 Butter             73.9050     Saturated Fat     45.61175
# 14 Butter             73.9050     Monosaturated Fat 19.46075
# 15 Butter             73.9050     Polysaturated Fat  2.86575
# 16 Butter-oil blend   73.2025     Saturated Fat     44.11725
# 17 Butter-oil blend   73.2025     Monosaturated Fat 19.17400
# 18 Butter-oil blend   73.2025     Polysaturated Fat  2.93775
# 19 Garlic sauce       73.0500     Saturated Fat     46.24000
# 20 Garlic sauce       73.0500     Monosaturated Fat 18.92000
# 21 Garlic sauce       73.0500     Polysaturated Fat  2.76400
# 22 Lemon-butter sauce 73.0200     Saturated Fat     46.23500
# 23 Lemon-butter sauce 73.0200     Monosaturated Fat 18.92000
# 24 Lemon-butter sauce 73.0200     Polysaturated Fat  2.74100
# 25 Pecans             69.4540     Saturated Fat      6.12420
# 26 Pecans             69.4540     Monosaturated Fat 38.89620
# 27 Pecans             69.4540     Polysaturated Fat 21.20800
# 28 Margarine          68.5200     Saturated Fat     13.37900
# 29 Margarine          68.5200     Monosaturated Fat 27.48500
# 30 Margarine          68.5200     Polysaturated Fat 25.57067
# 31 Pine nuts          68.3700     Saturated Fat      4.89900
# 32 Pine nuts          68.3700     Monosaturated Fat 18.76400
# 33 Pine nuts          68.3700     Polysaturated Fat 34.07100
# 34 Brazil nuts        67.1000     Saturated Fat     16.13400
# 35 Brazil nuts        67.1000     Monosaturated Fat 23.87900
# 36 Brazil nuts        67.1000     Polysaturated Fat 24.39900
# 37 Pork skin          65.5500     Saturated Fat     23.65700
# 38 Pork skin          65.5500     Monosaturated Fat 28.74600
# 39 Pork skin          65.5500     Polysaturated Fat 11.44200
# 40 Sesame seeds       61.2100     Saturated Fat      9.05500
# 41 Sesame seeds       61.2100     Monosaturated Fat 23.92400
# 42 Sesame seeds       61.2100     Polysaturated Fat 25.49100
# 43 Hazelnuts          60.7500     Saturated Fat      4.46400
# 44 Hazelnuts          60.7500     Monosaturated Fat 45.65200
# 45 Hazelnuts          60.7500     Polysaturated Fat  7.92000
# 46 Walnuts            59.5400     Saturated Fat      5.80250
# 47 Walnuts            59.5400     Monosaturated Fat  9.54700
# 48 Walnuts            59.5400     Polysaturated Fat 41.50650
# 49 Pesto sauce        59.1700     Saturated Fat      9.58400
# 50 Pesto sauce        59.1700     Monosaturated Fat 35.18000
# 51 Pesto sauce        59.1700     Polysaturated Fat 10.51500
# 52 Hollandaise sauce  56.6500     Saturated Fat     33.69000
# 53 Hollandaise sauce  56.6500     Monosaturated Fat 16.13500
# 54 Hollandaise sauce  56.6500     Polysaturated Fat  3.08900
# 55 Fry sauce          56.1600     Saturated Fat      8.78100
# 56 Fry sauce          56.1600     Monosaturated Fat 12.63600
# 57 Fry sauce          56.1600     Polysaturated Fat 33.52800
# 58 Almond butter      55.5000     Saturated Fat      6.55000
# 59 Almond butter      55.5000     Monosaturated Fat 32.44500
# 60 Almond butter      55.5000     Polysaturated Fat 13.61300

# %%
ggplot(
    data=top_lipids_V3_long, 
    aes(x = Category, y = Fat_Value, fill = Fat_Type))+ 
geom_col (position = "fill")+
scale_fill_manual(
    values = c("Monosaturated Fat" = "lightpink", "Polysaturated Fat" = "lightskyblue",
               "Saturated Fat" = "lightskyblue4"))+
theme(
   axis.text.x=element_text(angle=90,hjust = 1, vjust = 1,size = 12),
   axis.text.y=element_text(size = 12),
   axis.title.x = element_text(size = 14), 
   axis.title.y = element_text(size = 14),
   plot.title = element_text(hjust = 0.5, size = 16, face="bold"))+
labs(
    title= "Top 20 foods with more lipids content, by lipid",
    caption= "Source:ARS USDA Dataset", 
    y = "Proportion of fats",
    x = "Category",
    fill = "Type of Fat")

# %% [markdown]
# ## Vitamins analysis

# %%
###What foods have more vitamins?
top_vitamins<- average_measurements %>% 
               arrange(desc(`Vitamin B12`))%>% 
               select(Category,`Vitamin B12`, `Vitamin K`, `Thiamin`,
                      `Vitamin B6`, Riboflavin, Niacin,`Vitamin C`,
                      `Vitamin A - RAE`, `Vitamin E`)%>%
               slice_head(n = 20)
as_tibble(top_vitamins)
# Out:
#    Category                                          Vitamin B12 Vitamin K
# 1  Beef liver                                        76.21500     3.6000000
# 2  Liver                                             50.67000     3.3000000
# 3  Liver dumpling                                    45.89000    40.6000000
# 4  Octopus                                           36.66800     2.5200000
# 5  Stewed variety meats                              27.45000     4.8000000
# 6  Kidney                                            24.69000     0.0000000
# 7  Cereal (Kellogg's All-Bran Complete Wheat Flakes) 21.00000     1.4000000
# 8  Liverwurst                                        20.09000     1.6000000
# 9  Cereal (Kellogg's Special K)                      19.40000     0.1000000
# 10 Cereal (Kellogg's All-Bran)                       18.80000     5.2000000
# 11 Mussels                                           18.33333     0.1666667
# 12 Cereal (Kashi Heart to Heart Honey Toasted Oat)   18.00000     2.4000000
# 13 Chicken liver                                     15.89000     0.8500000
# 14 Sardines                                          13.29000     1.4500000
# 15 Herring                                           13.27909     2.7454545
# 16 Roe                                               12.79667     1.8333333
# 17 Cereal (Kellogg's Smart Start Strong)             12.00000     1.1000000
# 18 Oyster fritter                                    11.99000    24.3000000
# 19 Clams                                             11.92273     4.4000000
# 20 Clam cake or patty                                11.38000    24.0000000
#    Thiamin    Vitamin B6  Riboflavin Niacin     Vitamin C   Vitamin A - RAE
# 1  0.18400000  1.01350000 3.39600000 17.3540000   1.3000000 8521.00000
# 2  0.12400000  0.67500000 2.09600000 10.7130000   2.4000000 4727.00000
# 3  0.21100000  0.71000000 2.35000000 12.1000000   2.7000000 6255.00000
# 4  0.07840000  0.69800000 0.08900000  4.1670000   8.9800000   88.40000
# 5  0.10600000  0.49100000 1.36900000  7.4420000  21.1000000 3670.00000
# 6  0.15900000  0.38800000 2.94500000  3.8870000   0.0000000    0.00000
# 7  5.17000000  6.90000000 5.86000000 69.0000000 207.0000000  776.00000
# 8  0.24900000  0.33000000 1.52500000  8.3680000   0.0000000 4220.00000
# 9  1.69000000  6.44000000 1.91000000 22.6000000  68.0000000  500.00000
# 10 2.27000000 12.00000000 2.71000000 14.8000000  20.0000000  522.00000
# 11 0.25533333  0.07666667 0.33466667  2.4446667  11.1333333   73.33333
# 12 0.31000000  6.05000000 0.07000000  1.0000000  91.0000000  189.00000
# 13 0.28750000  0.66650000 1.91350000 10.0920000  22.0000000 3378.50000
# 14 0.10700000  0.28825000 0.32125000  5.7345000   0.6000000   42.50000
# 15 0.12972727  0.33600000 0.30236364  4.2740909   0.8000000   74.00000
# 16 0.23633333  0.21633333 0.75500000  1.3736667   9.9333333  148.66667
# 17 3.00000000  4.00000000 3.40000000 40.0000000  30.0000000  688.00000
# 18 0.12500000  0.08600000 0.17300000  1.0560000   3.1000000   80.00000
# 19 0.05645455  0.02100000 0.07427273  0.7303636   0.2636364  102.90909
# 20 0.04700000  0.03700000 0.10100000  0.5830000   0.3000000  118.00000
#    Vitamin E
# 1   0.4850000
# 2   0.3600000
# 3   1.6700000
# 4   2.3160000
# 5   0.4600000
# 6   0.0800000
# 7  46.3500000
# 8   0.3500000
# 9  15.3000000
# 10  1.1900000
# 11  0.9166667
# 12 60.9700000
# 13  0.9000000
# 14  2.0500000
# 15  1.7009091
# 16  5.9633333
# 17 27.0000000
# 18  1.6800000
# 19  1.1754545
# 20  1.8500000

# %%
top_vitamins <- top_vitamins%>%
                mutate(total_vitamins = rowSums(across(c(
                                          `Vitamin B12`, `Vitamin K`,`Thiamin`,`Vitamin B6`, 
                                           Riboflavin, Niacin,`Vitamin C`, `Vitamin A - RAE`, 
                                           `Vitamin E`)), na.rm = TRUE)) %>%
               arrange(desc(total_vitamins))
as_tibble(top_vitamins)
# Out:
#    Category                                          Vitamin B12 Vitamin K
# 1  Beef liver                                        76.21500     3.6000000
# 2  Liver dumpling                                    45.89000    40.6000000
# 3  Liver                                             50.67000     3.3000000
# 4  Liverwurst                                        20.09000     1.6000000
# 5  Stewed variety meats                              27.45000     4.8000000
# 6  Chicken liver                                     15.89000     0.8500000
# 7  Cereal (Kellogg's All-Bran Complete Wheat Flakes) 21.00000     1.4000000
# 8  Cereal (Kellogg's Smart Start Strong)             12.00000     1.1000000
# 9  Cereal (Kellogg's Special K)                      19.40000     0.1000000
# 10 Cereal (Kellogg's All-Bran)                       18.80000     5.2000000
# 11 Cereal (Kashi Heart to Heart Honey Toasted Oat)   18.00000     2.4000000
# 12 Roe                                               12.79667     1.8333333
# 13 Clam cake or patty                                11.38000    24.0000000
# 14 Octopus                                           36.66800     2.5200000
# 15 Oyster fritter                                    11.99000    24.3000000
# 16 Clams                                             11.92273     4.4000000
# 17 Mussels                                           18.33333     0.1666667
# 18 Herring                                           13.27909     2.7454545
# 19 Sardines                                          13.29000     1.4500000
# 20 Kidney                                            24.69000     0.0000000
#    Thiamin    Vitamin B6  Riboflavin Niacin     Vitamin C   Vitamin A - RAE
# 1  0.18400000  1.01350000 3.39600000 17.3540000   1.3000000 8521.00000
# 2  0.21100000  0.71000000 2.35000000 12.1000000   2.7000000 6255.00000
# 3  0.12400000  0.67500000 2.09600000 10.7130000   2.4000000 4727.00000
# 4  0.24900000  0.33000000 1.52500000  8.3680000   0.0000000 4220.00000
# 5  0.10600000  0.49100000 1.36900000  7.4420000  21.1000000 3670.00000
# 6  0.28750000  0.66650000 1.91350000 10.0920000  22.0000000 3378.50000
# 7  5.17000000  6.90000000 5.86000000 69.0000000 207.0000000  776.00000
# 8  3.00000000  4.00000000 3.40000000 40.0000000  30.0000000  688.00000
# 9  1.69000000  6.44000000 1.91000000 22.6000000  68.0000000  500.00000
# 10 2.27000000 12.00000000 2.71000000 14.8000000  20.0000000  522.00000
# 11 0.31000000  6.05000000 0.07000000  1.0000000  91.0000000  189.00000
# 12 0.23633333  0.21633333 0.75500000  1.3736667   9.9333333  148.66667
# 13 0.04700000  0.03700000 0.10100000  0.5830000   0.3000000  118.00000
# 14 0.07840000  0.69800000 0.08900000  4.1670000   8.9800000   88.40000
# 15 0.12500000  0.08600000 0.17300000  1.0560000   3.1000000   80.00000
# 16 0.05645455  0.02100000 0.07427273  0.7303636   0.2636364  102.90909
# 17 0.25533333  0.07666667 0.33466667  2.4446667  11.1333333   73.33333
# 18 0.12972727  0.33600000 0.30236364  4.2740909   0.8000000   74.00000
# 19 0.10700000  0.28825000 0.32125000  5.7345000   0.6000000   42.50000
# 20 0.15900000  0.38800000 2.94500000  3.8870000   0.0000000    0.00000
#    Vitamin E  total_vitamins
# 1   0.4850000 8624.54750
# 2   1.6700000 6361.23100
# 3   0.3600000 4797.33800
# 4   0.3500000 4252.51200
# 5   0.4600000 3733.21800
# 6   0.9000000 3431.09950
# 7  46.3500000 1138.68000
# 8  27.0000000  808.50000
# 9  15.3000000  635.44000
# 10  1.1900000  598.97000
# 11 60.9700000  368.80000
# 12  5.9633333  181.77467
# 13  1.8500000  156.29800
# 14  2.3160000  143.91640
# 15  1.6800000  122.51000
# 16  1.1754545  121.55300
# 17  0.9166667  106.99467
# 18  1.7009091   97.56764
# 19  2.0500000   66.34100
# 20  0.0800000   32.14900

# %%
top_vitamins_long <- top_vitamins %>%
                     pivot_longer(cols = c(`Vitamin B12`, `Vitamin K`,`Thiamin`,`Vitamin B6`, 
                                          Riboflavin, Niacin,`Vitamin C`, `Vitamin A - RAE`, 
                                          `Vitamin E`),
                                  names_to = "Vitamin_Type",
                                  values_to = "Vitamin_value")
as_tibble(top_vitamins_long)
# Out:
#     Category       total_vitamins Vitamin_Type    Vitamin_value
# 1   Beef liver     8624.548       Vitamin B12       76.2150
# 2   Beef liver     8624.548       Vitamin K          3.6000
# 3   Beef liver     8624.548       Thiamin            0.1840
# 4   Beef liver     8624.548       Vitamin B6         1.0135
# 5   Beef liver     8624.548       Riboflavin         3.3960
# 6   Beef liver     8624.548       Niacin            17.3540
# 7   Beef liver     8624.548       Vitamin C          1.3000
# 8   Beef liver     8624.548       Vitamin A - RAE 8521.0000
# 9   Beef liver     8624.548       Vitamin E          0.4850
# 10  Liver dumpling 6361.231       Vitamin B12       45.8900
# 11  Liver dumpling 6361.231       Vitamin K         40.6000
# 12  Liver dumpling 6361.231       Thiamin            0.2110
# 13  Liver dumpling 6361.231       Vitamin B6         0.7100
# 14  Liver dumpling 6361.231       Riboflavin         2.3500
# 15  Liver dumpling 6361.231       Niacin            12.1000
# 16  Liver dumpling 6361.231       Vitamin C          2.7000
# 17  Liver dumpling 6361.231       Vitamin A - RAE 6255.0000
# 18  Liver dumpling 6361.231       Vitamin E          1.6700
# 19  Liver          4797.338       Vitamin B12       50.6700
# 20  Liver          4797.338       Vitamin K          3.3000
# 21  Liver          4797.338       Thiamin            0.1240
# 22  Liver          4797.338       Vitamin B6         0.6750
# 23  Liver          4797.338       Riboflavin         2.0960
# 24  Liver          4797.338       Niacin            10.7130
# 25  Liver          4797.338       Vitamin C          2.4000
# 26  Liver          4797.338       Vitamin A - RAE 4727.0000
# 27  Liver          4797.338       Vitamin E          0.3600
# 28  Liverwurst     4252.512       Vitamin B12       20.0900
# 29  Liverwurst     4252.512       Vitamin K          1.6000
# 30  Liverwurst     4252.512       Thiamin            0.2490
# ⋮   ⋮              ⋮              ⋮               ⋮
# 151 Mussels        106.99467      Vitamin C       11.1333333
# 152 Mussels        106.99467      Vitamin A - RAE 73.3333333
# 153 Mussels        106.99467      Vitamin E        0.9166667
# 154 Herring         97.56764      Vitamin B12     13.2790909
# 155 Herring         97.56764      Vitamin K        2.7454545
# 156 Herring         97.56764      Thiamin          0.1297273
# 157 Herring         97.56764      Vitamin B6       0.3360000
# 158 Herring         97.56764      Riboflavin       0.3023636
# 159 Herring         97.56764      Niacin           4.2740909
# 160 Herring         97.56764      Vitamin C        0.8000000
# 161 Herring         97.56764      Vitamin A - RAE 74.0000000
# 162 Herring         97.56764      Vitamin E        1.7009091
# 163 Sardines        66.34100      Vitamin B12     13.2900000
# 164 Sardines        66.34100      Vitamin K        1.4500000
# 165 Sardines        66.34100      Thiamin          0.1070000
# 166 Sardines        66.34100      Vitamin B6       0.2882500
# 167 Sardines        66.34100      Riboflavin       0.3212500
# 168 Sardines        66.34100      Niacin           5.7345000
# 169 Sardines        66.34100      Vitamin C        0.6000000
# 170 Sardines        66.34100      Vitamin A - RAE 42.5000000
# 171 Sardines        66.34100      Vitamin E        2.0500000
# 172 Kidney          32.14900      Vitamin B12     24.6900000
# 173 Kidney          32.14900      Vitamin K        0.0000000
# 174 Kidney          32.14900      Thiamin          0.1590000
# 175 Kidney          32.14900      Vitamin B6       0.3880000
# 176 Kidney          32.14900      Riboflavin       2.9450000
# 177 Kidney          32.14900      Niacin           3.8870000
# 178 Kidney          32.14900      Vitamin C        0.0000000
# 179 Kidney          32.14900      Vitamin A - RAE  0.0000000
# 180 Kidney          32.14900      Vitamin E        0.0800000

# %%
ggplot(
    top_vitamins_long, 
    aes(x = Category, y = Vitamin_value, fill = Vitamin_Type)) +
geom_col(position = "fill") + 
scale_fill_manual(values = c(
    "Vitamin B12" = "darkorange4", 
    "Vitamin K" = "goldenrod1",
    "Thiamin" = "tan3",
    "Vitamin B6" = "darkorchid2",
    "Riboflavin" = "yellow4",
    "Niacin" = "cyan4",
    "Vitamin C" = "paleturquoise3",
    "Vitamin A - RAE" = "darkolivegreen3",
    "Vitamin E" = "darkorange" )) +
  theme(
      axis.text.x = element_text(angle = 70, hjust = 1, vjust = 1,size = 12),
      axis.text.y=element_text(size = 12),
      axis.title.x = element_text(size = 14), 
      axis.title.y = element_text(size = 14),
      plot.title = element_text(hjust = 0.5, size = 16, face="bold"))+
  labs(
    title = "Top 20 foods with more vitamin content",
    caption = "Source: ARS USDA Dataset",
    y = "Proportion of vitamins",
    x = "Category",
    fill = "Type of vitamin")

# %% [markdown]
# ## Vitamins vs sugar and fat analysis
# A rich vitamins food is not always a totally health one, so we compared the contents of food with more vitamins versus its fat and sugar content, so people get nuanced approach highlights and understands the complexity of nutritional data and underscores the importance of detailed and context-aware analysis.

# %%
top_vitamins_sugarfat <- average_measurements %>%
                   mutate(total_vitamins = rowSums(across(c(`Vitamin B12`, `Vitamin K`, `Thiamin`, `Vitamin B6`, 
                                      Riboflavin, Niacin, `Vitamin C`, `Vitamin A - RAE`, 
                                      `Vitamin E`)), na.rm = TRUE),  
                            Sugar_category = cut(`Sugar Total`, 
                                     breaks = c(0, 20, 30, Inf), 
                                     labels = c("0-20 g", "21-30 g", "31+ g"),
                                      right = FALSE),
                           Fat_category = cut(`Polysaturated Fat`, 
                                 breaks = c(0,3, 5, 10, Inf), 
                                 labels = c("0-2","3-5 g", "6-10 g", "11+ g"),
                                  right = FALSE) ) %>%
                    arrange(desc(total_vitamins)) %>%
                    select(Category, total_vitamins,  `Sugar Total`, Sugar_category,
                          `Polysaturated Fat`, Fat_category) %>%
                    slice_head(n = 20)
as_tibble (top_vitamins_sugarfat)
# Out:
#    Category                                    total_vitamins Sugar Total
# 1  Beef liver                                  8624.548        0.000
# 2  Liver dumpling                              6361.231        0.910
# 3  Liver                                       4797.338        1.780
# 4  Liverwurst                                  4252.512        0.000
# 5  Stewed variety meats                        3733.218        1.940
# 6  Chicken liver                               3431.099        0.010
# 7  Parsley                                     2196.337        0.850
# 8  Livers                                      1769.605        1.230
# 9  Nutrition bar (Balance Original Bar)        1528.797       34.890
# 10 Cereal (Kellogg's Smorz)                    1405.123       43.700
# 11 Vegetable mixture                           1403.063       19.810
# 12 Dandelion greens                            1342.024        0.725
# 13 Cereal (Kellogg's Cocoa Krispies)           1293.990       38.600
# 14 Cereal (Kellogg's Rice Krispies)            1256.547        9.870
# 15 Nutritional powder mix (Slim Fast)          1234.366       38.020
# 16 Nutrition bar (Zone Perfect Classic Crunch) 1224.250       27.000
# 17 Nutrition bar or meal replacement bar       1224.250       27.000
# 18 Sweet potato chips                          1215.028        8.780
# 19 Nutrition bar (Slim Fast Original Meal Bar) 1206.700       25.000
# 20 Nutrition bar (South Beach Living Meal Bar) 1206.700       25.000
#    Sugar_category Polysaturated Fat Fat_category
# 1  0-20 g          1.056            0-2
# 2  0-20 g          4.247            3-5 g
# 3  0-20 g          0.853            0-2
# 4  0-20 g          3.193            3-5 g
# 5  0-20 g          0.513            0-2
# 6  0-20 g          2.178            0-2
# 7  0-20 g          0.124            0-2
# 8  0-20 g          3.840            3-5 g
# 9  31+ g           1.969            0-2
# 10 31+ g           0.231            0-2
# 11 0-20 g          5.304            6-10 g
# 12 0-20 g          0.729            0-2
# 13 31+ g           0.100            0-2
# 14 0-20 g          0.626            0-2
# 15 31+ g           1.190            0-2
# 16 21-30 g         4.804            3-5 g
# 17 21-30 g         4.804            3-5 g
# 18 0-20 g         12.163            11+ g
# 19 21-30 g         1.132            0-2
# 20 21-30 g         1.132            0-2

# %%
top_vitamins_sugarfat <- top_vitamins_sugarfat %>%
                         group_by(Fat_category) %>%
                         filter(n() > 0) %>%
                         ungroup()
top_vitamins_sugarfat
# Out:
#    Category                                    total_vitamins Sugar Total
# 1  Beef liver                                  8624.548        0.000
# 2  Liver dumpling                              6361.231        0.910
# 3  Liver                                       4797.338        1.780
# 4  Liverwurst                                  4252.512        0.000
# 5  Stewed variety meats                        3733.218        1.940
# 6  Chicken liver                               3431.099        0.010
# 7  Parsley                                     2196.337        0.850
# 8  Livers                                      1769.605        1.230
# 9  Nutrition bar (Balance Original Bar)        1528.797       34.890
# 10 Cereal (Kellogg's Smorz)                    1405.123       43.700
# 11 Vegetable mixture                           1403.063       19.810
# 12 Dandelion greens                            1342.024        0.725
# 13 Cereal (Kellogg's Cocoa Krispies)           1293.990       38.600
# 14 Cereal (Kellogg's Rice Krispies)            1256.547        9.870
# 15 Nutritional powder mix (Slim Fast)          1234.366       38.020
# 16 Nutrition bar (Zone Perfect Classic Crunch) 1224.250       27.000
# 17 Nutrition bar or meal replacement bar       1224.250       27.000
# 18 Sweet potato chips                          1215.028        8.780
# 19 Nutrition bar (Slim Fast Original Meal Bar) 1206.700       25.000
# 20 Nutrition bar (South Beach Living Meal Bar) 1206.700       25.000
#    Sugar_category Polysaturated Fat Fat_category
# 1  0-20 g          1.056            0-2
# 2  0-20 g          4.247            3-5 g
# 3  0-20 g          0.853            0-2
# 4  0-20 g          3.193            3-5 g
# 5  0-20 g          0.513            0-2
# 6  0-20 g          2.178            0-2
# 7  0-20 g          0.124            0-2
# 8  0-20 g          3.840            3-5 g
# 9  31+ g           1.969            0-2
# 10 31+ g           0.231            0-2
# 11 0-20 g          5.304            6-10 g
# 12 0-20 g          0.729            0-2
# 13 31+ g           0.100            0-2
# 14 0-20 g          0.626            0-2
# 15 31+ g           1.190            0-2
# 16 21-30 g         4.804            3-5 g
# 17 21-30 g         4.804            3-5 g
# 18 0-20 g         12.163            11+ g
# 19 21-30 g         1.132            0-2
# 20 21-30 g         1.132            0-2

# %%
ggplot(
    data=top_vitamins_sugarfat)+ 
scale_fill_manual(values = c(
    "0-20 g" = "pink2", 
    "21-30 g" = "skyblue",
    "31+ g" = "plum4"
    )) +
geom_col (mapping=aes(x=Category, y=total_vitamins,fill=Sugar_category))+
theme(
    axis.text.x = element_text(angle = 70, hjust = 1, vjust = 1,size = 11),
    axis.text.y=element_text(size = 12),
    axis.title.x = element_text(size = 14), 
    axis.title.y = element_text(size = 14),
    plot.title = element_text(hjust = 0.5, size = 16, face="bold"))+

labs(
title= "Top 20 foods with more vitamins, with their sugar content",
caption= "Source:ARS USDA Dataset", y= "Total vitamins (g)")+
facet_wrap(~Sugar_category, scales = "free_x")

# %%
ggplot(
    data=top_vitamins_sugarfat)+ 
scale_fill_manual(values = c( 
    "0-2"= "darkseagreen3",
    "3-5 g"= "pink2",
    "6-10 g"= "skyblue",
    "11+ g"= "plum4"
    ))+
geom_col(mapping=aes(x=Category, y=total_vitamins,fill=Fat_category))+
theme(
    axis.text.x = element_text(angle = 70, hjust = 1, vjust = 1,size = 10),
    axis.text.y=element_text(size = 12),
    axis.title.x = element_text(size = 11), 
    axis.title.y = element_text(size = 14),
    plot.title = element_text(hjust = 0.5, size = 16, face="bold"))+

labs(
title= "Top 20 foods with more vitamins, with their fat content",
caption= "Source:ARS USDA Dataset", y= "Total vitamins (g)")+
facet_wrap(~Fat_category, scales = "free_x")
